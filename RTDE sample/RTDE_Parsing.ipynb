# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
file_path = "./rtde_registers_20250410_151405.csv"  # 실제 파일 경로로 변경해야 함

df = pd.read_csv(file_path, index_col=0, parse_dates=True)
df
# Out:
# /tmp/ipykernel_99057/3123116886.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(file_path, index_col=0, parse_dates=True)
#                timer  WCR IN  Welding Current  Welding Voltage  X offset  \
# 1.744266e+09   1.088     0.0              0.0              0.0       0.0
# 1.744266e+09   1.192     0.0              0.0              0.0       0.0
# 1.744266e+09   1.288     0.0              0.0              0.0       0.0
# 1.744266e+09   1.384     0.0              0.0              0.0       0.0
# 1.744266e+09   1.472     0.0              0.0              0.0       0.0
# ...              ...     ...              ...              ...       ...
# 1.744266e+09  50.184     0.0              0.0              0.0       0.0
# 1.744266e+09  50.184     0.0              0.0              0.0       0.0
# ...

# %%
df['x']
# Out:
# 1.744266e+09     -4.626790
# 1.744266e+09     -6.555548
# 1.744266e+09     -8.335924
# 1.744266e+09    -10.116197
# 1.744266e+09    -10.424000
#                    ...
# 1.744266e+09   -355.511481
# 1.744266e+09   -355.511481
# 1.744266e+09   -355.511481
# 1.744266e+09   -355.511481
# 1.744266e+09   -355.511481
# Name: x, Length: 552, dtype: float64

# %%
df['y']
# Out:
# 1.744266e+09    -0.107292
# 1.744266e+09     0.679822
# 1.744266e+09     1.406281
# 1.744266e+09     2.132878
# 1.744266e+09     1.985833
#                   ...
# 1.744266e+09   -15.624035
# 1.744266e+09   -15.624035
# 1.744266e+09   -15.624035
# 1.744266e+09   -15.624035
# 1.744266e+09   -15.624035
# Name: y, Length: 552, dtype: float64

# %%
# 여러 열 플롯하기
df[['y']].plot()
plt.title('Plot')
plt.xlabel('time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
